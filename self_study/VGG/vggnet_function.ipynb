# %%
import tensorflow as tf

import numpy as np

# %%
# Data Prepare START

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()



x_train, x_test = x_train / 255.0, x_test / 255.0



x_train = np.expand_dims(x_train, axis=-1)

x_test = np.expand_dims(x_test, axis=-1)

# Data Prepare END




#필터 크기 3*3으로 고정
#reduce_size=True 맥스 풀링 하는지
def vgg_block(in_layer, n_conv, n_filter, filter_size=(3, 3), reduce_size=True):

    layer = in_layer

    #정의한 컨볼루션 횟수만큼 진행
    for i in range(n_conv):

        layer = tf.keras.layers.Conv2D(n_filter, filter_size, padding='SAME', activation='relu')(layer)



    if reduce_size:

        layer = tf.keras.layers.MaxPool2D((2, 2))(layer)

    return layer





input_layer = tf.keras.layers.Input(shape=(28, 28, 1))

vgg_block01 = vgg_block(input_layer, 2, 64) # 14x14x64

vgg_block02 = vgg_block(vgg_block01, 2, 128) # 7x7x128

vgg_block03 = vgg_block(vgg_block02, 3, 256) # 3x3x256

vgg_block04 = vgg_block(vgg_block03, 3, 512) # 1x1x512



flatten = tf.keras.layers.Flatten()(vgg_block04)

dense01 = tf.keras.layers.Dense(256, activation='relu')(flatten)

output = tf.keras.layers.Dense(10, activation='softmax')(dense01)



model = tf.keras.models.Model(input_layer, output)



model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.summary()



model.fit(x_train, y_train, batch_size=64, epochs=10,

          validation_data=(x_test, y_test))
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 28, 28, 64)        640
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 14, 128)       73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 14, 128)       147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 7, 7, 256)         295168
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 7, 7, 256)         590080
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 7, 7, 256)         590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 3, 3, 256)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 3, 3, 512)         1180160
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 3, 3, 512)         2359808
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 3, 3, 512)         2359808
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               131328
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 7,768,010
# Trainable params: 7,768,010
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 938/938 [==============================] - 278s 296ms/step - loss: 0.3906 - accuracy: 0.8651 - val_loss: 0.0685 - val_accuracy: 0.9812
# Epoch 2/10
# 938/938 [==============================] - 286s 305ms/step - loss: 0.0654 - accuracy: 0.9822 - val_loss: 0.0486 - val_accuracy: 0.9864
# Epoch 3/10
# 938/938 [==============================] - 273s 291ms/step - loss: 0.0485 - accuracy: 0.9868 - val_loss: 0.0359 - val_accuracy: 0.9900
# Epoch 4/10
# 938/938 [==============================] - 273s 291ms/step - loss: 0.0417 - accuracy: 0.9892 - val_loss: 0.0677 - val_accuracy: 0.9856
# Epoch 5/10
# 938/938 [==============================] - 274s 292ms/step - loss: 0.0396 - accuracy: 0.9898 - val_loss: 0.0746 - val_accuracy: 0.9845
# Epoch 6/10
# 938/938 [==============================] - 270s 287ms/step - loss: 0.0367 - accuracy: 0.9910 - val_loss: 0.0352 - val_accuracy: 0.9917
# Epoch 7/10
# 938/938 [==============================] - 269s 287ms/step - loss: 0.0263 - accuracy: 0.9931 - val_loss: 0.0347 - val_accuracy: 0.9915
# Epoch 8/10
# 938/938 [==============================] - 269s 287ms/step - loss: 0.0270 - accuracy: 0.9932 - val_loss: 0.0809 - val_accuracy: 0.9801
# Epoch 9/10
# 938/938 [==============================] - 269s 286ms/step - loss: 0.0264 - accuracy: 0.9936 - val_loss: 0.0369 - val_accuracy: 0.9912
# Epoch 10/10
# 938/938 [==============================] - 4062s 4s/step - loss: 0.0201 - accuracy: 0.9946 - val_loss: 0.0334 - val_accuracy: 0.9925
